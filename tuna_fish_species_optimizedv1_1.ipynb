# %% [markdown]
# <a href="https://colab.research.google.com/github/NerminWEST/Kaggle_Dataset_Fish_Model1.0/blob/main/tuna_fish_species_optimizedv1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TUNA SPECIES DETECTION WITH YOLOv8 - GOOGLE COLAB NOTEBOOK
#
# # Author: Nermin
# # Dataset: Kaggle Tuna Species Data
# # Model: YOLOv8

# %% [markdown]
#  CELL 1: Check GPU and Install Dependencies

# %%
import os
print(" Checking GPU availability...")
# !nvidia-smi

print("\n Installing required packages...")
# !pip install -q ultralytics roboflow kaggle pillow matplotlib

print("\n Installation complete!")
# Out:
#  Checking GPU availability...
# Tue Dec  9 23:21:48 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
#
#  Installing required packages...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 39.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 65.6 MB/s eta 0:00:00
#
#  Installation complete!

# %%
from google.colab import drive
import os

# Mount Google Drive
print("📁 Mounting Google Drive...")
drive.mount('/content/drive')

# Set the path to your dataset
dataset_path = '/content/drive/MyDrive/classification-tuna-species-dataset'

# Verify the dataset exists
if os.path.exists(dataset_path):
    print(f"\n✅ Dataset found at: {dataset_path}")

    # Check the structure
    print("\n📂 Dataset structure:")
    for folder in os.listdir(dataset_path):
        folder_path = os.path.join(dataset_path, folder)
        if os.path.isdir(folder_path):
            num_files = len([f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
            print(f"   {folder}: {num_files} images")
else:
    print(f"\n❌ Dataset not found at: {dataset_path}")
    print("Please check the path in your Google Drive")
# Out:
# 📁 Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ✅ Dataset found at: /content/drive/MyDrive/classification-tuna-species-dataset
#
# 📂 Dataset structure:
#    yellowfin: 127 images
#    bigeye: 122 images
#    longfin: 243 images
#    bluefin: 5 images

# %%
import shutil
from sklearn.model_selection import train_test_split
from pathlib import Path

# Create directory structure
print("Creating YOLOv8 directory structure...")
yolo_dataset = Path("yolo_tuna_dataset")
for split in ['train', 'val', 'test']:
    (yolo_dataset / 'images' / split).mkdir(parents=True, exist_ok=True)
    (yolo_dataset / 'labels' / split).mkdir(parents=True, exist_ok=True)

# Get species from the correct Google Drive path
dataset_path = Path("/content/drive/MyDrive/classification-tuna-species-dataset")
species_list = sorted([f.name for f in dataset_path.iterdir() if f.is_dir()])
class_mapping = {species: idx for idx, species in enumerate(species_list)}

print(f"\n✅ Class mapping ({len(species_list)} species):")
for species, idx in class_mapping.items():
    print(f"  {idx}: {species}")

# Collect all image files
all_files = []
for species in species_list:
    species_folder = dataset_path / species
    images = list(species_folder.glob("*.png")) + list(species_folder.glob("*.jpg")) + \
             list(species_folder.glob("*.jpeg")) + list(species_folder.glob("*.JPG")) + \
             list(species_folder.glob("*.PNG"))
    all_files.extend([(img, species) for img in images])

print(f"\n📊 Total files to process: {len(all_files)}")

if len(all_files) < 10:
    print("⚠️  WARNING: Very few images! Consider:")
    print("   1. Using a larger dataset")
    print("   2. Web scraping more tuna images")
    print("   3. Using Google Images")

# Split dataset - for small datasets, use larger validation set
if len(all_files) >= 10:
    # At least 1 test image
    test_size = max(0.15, 1.0 / len(all_files))
    train_val, test = train_test_split(all_files, test_size=test_size, random_state=42)

    # At least 1 validation image
    val_size = max(0.2, 1.0 / len(train_val))
    train, val = train_test_split(train_val, test_size=val_size, random_state=42)
else:
    # Too few images - use all for training, warn user
    print("\n⚠️  Too few images for proper split. Using all for training.")
    train = all_files
    val = all_files[:max(1, len(all_files)//4)]  # Use some for validation
    test = all_files[:max(1, len(all_files)//5)]  # Use some for testing

print(f"  • Train: {len(train)} images")
print(f"  • Val: {len(val)} images")
print(f"  • Test: {len(test)} images")

# Function to create full-image bounding box annotation
def create_full_bbox_label(class_id):
    """Create a YOLO label for full image (assuming entire image is the fish)"""
    # YOLO format: class_id center_x center_y width height (normalized 0-1)
    return f"{class_id} 0.5 0.5 1.0 1.0\n"

# Process and copy files
def process_split(file_list, split_name):
    print(f"\n🔄 Processing {split_name} split...")
    success_count = 0
    for idx, (img_path, species) in enumerate(file_list):
        try:
            class_id = class_mapping[species]

            # Copy image with unique filename
            new_name = f"{species}_{idx}{img_path.suffix}"
            img_dest = yolo_dataset / 'images' / split_name / new_name
            shutil.copy(img_path, img_dest)

            # Create label file
            label_dest = yolo_dataset / 'labels' / split_name / f"{species}_{idx}.txt"
            with open(label_dest, 'w') as f:
                f.write(create_full_bbox_label(class_id))

            success_count += 1
        except Exception as e:
            print(f"❌ Error processing {img_path.name}: {e}")

    print(f"✅ Successfully processed {success_count} images")
    return success_count

train_count = process_split(train, 'train')
val_count = process_split(val, 'val')
test_count = process_split(test, 'test')

print("\n🎉 Dataset preparation complete!")
print(f"📈 Final counts:")
print(f"   Train: {train_count} images")
print(f"   Val: {val_count} images")
print(f"   Test: {test_count} images")

if train_count < 20:
    print("\n💡 TIP: With this small dataset, we'll use heavy augmentation during training!")
# Out:
# Creating YOLOv8 directory structure...
#
# ✅ Class mapping (4 species):
#   0: bigeye
#   1: bluefin
#   2: longfin
#   3: yellowfin
#
# 📊 Total files to process: 497
#   • Train: 337 images
#   • Val: 85 images
#   • Test: 75 images
#
# 🔄 Processing train split...
# ✅ Successfully processed 337 images
#
# 🔄 Processing val split...
# ✅ Successfully processed 85 images
#
# 🔄 Processing test split...
# ✅ Successfully processed 75 images
#
# 🎉 Dataset preparation complete!
# 📈 Final counts:
#    Train: 337 images
#    Val: 85 images
#    Test: 75 images

# %%
import yaml

data_yaml = {
    'path': str(yolo_dataset.absolute()),
    'train': 'images/train',
    'val': 'images/val',
    'test': 'images/test',
    'nc': len(species_list),
    'names': species_list
}

yaml_path = yolo_dataset / 'data.yaml'
with open(yaml_path, 'w') as f:
    yaml.dump(data_yaml, f, default_flow_style=False)

print(" Created data.yaml:")
print(yaml.dump(data_yaml, default_flow_style=False))

# ============================================================================
# CELL 6: Train YOLOv8 Model (OPTIMIZED FOR SMALL DATASET)
# ============================================================================
"""
Training with HEAVY augmentation to compensate for small dataset
This will take 10-30 minutes depending on GPU
"""

from ultralytics import YOLO

print("Starting YOLOv8 training with aggressive augmentation...\n")
print(" Note: With only 20 images, expect moderate accuracy.")
print("    The model will learn patterns but may overfit.\n")

# Load pretrained YOLOv8 model (using smallest/fastest)
model = YOLO('yolov8n.pt')  # Nano - best for small datasets

# Train with HEAVY augmentation for small dataset
results = model.train(
    data=str(yaml_path),
    epochs=200,              # More epochs for small dataset
    imgsz=640,              # Image size
    batch=8,                # Small batch for small dataset
    patience=50,            # More patience
    save=True,
    device=0,               # Use GPU
    workers=2,              # Fewer workers for small dataset
    project='tuna_runs',
    name='tuna_detection',
    exist_ok=True,
    pretrained=True,
    optimizer='Adam',
    verbose=True,
    seed=42,

    # HEAVY AUGMENTATION for small dataset
    hsv_h=0.03,            # Hue augmentation
    hsv_s=0.7,             # Saturation augmentation
    hsv_v=0.4,             # Value augmentation
    degrees=20,            # Rotation up to 20 degrees
    translate=0.2,         # Translation
    scale=0.8,             # Scaling
    shear=5,               # Shear transformation
    perspective=0.001,     # Perspective transformation
    flipud=0.5,            # Flip upside-down probability
    fliplr=0.5,            # Flip left-right probability
    mosaic=1.0,            # Mosaic augmentation
    mixup=0.3,             # Mixup augmentation
    copy_paste=0.3,        # Copy-paste augmentation

    # Regularization
    weight_decay=0.001,    # Weight decay
    dropout=0.2,           # Dropout for regularization

    # Learning rate
    lr0=0.001,            # Initial learning rate
    lrf=0.01,             # Final learning rate

    # Other
    val=True,
    plots=True,
    save_period=10,       # Save checkpoint every 10 epochs
)

print("\n Training complete!")
print(f" Best model saved at: tuna_runs/tuna_detection/weights/best.pt")
print("\n Next: Evaluate the model to see how well it learned!")
# Out:
#  Created data.yaml:
# names:
# - bigeye
# - bluefin
# - longfin
# - yellowfin
# nc: 4
# path: /content/yolo_tuna_dataset
# test: images/test
# train: images/train
# val: images/val
#
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Starting YOLOv8 training with aggressive augmentation...
#
#  Note: With only 20 images, expect moderate accuracy.
#     The model will learn patterns but may overfit.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 320.6MB/s 0.0s
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.3, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=yolo_tuna_dataset/data.yaml, degrees=20, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.2, dynamic=False, embed=None, epochs=200, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.5, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.03, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.3, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=tuna_detection, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=50, perspective=0.001, plots=True, pose=12.0, pretrained=True, profile=False, project=tuna_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/tuna_runs/tuna_detection, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.8, seed=42, shear=5, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.2, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.001, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 34.9MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 129 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 269.2MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 289.9±70.3 MB/s, size: 9.6 KB)
# train: Scanning /content/yolo_tuna_dataset/labels/train... 337 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 337/337 1.8Kit/s 0.2s
# train: New cache created: /content/yolo_tuna_dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 286.2±158.1 MB/s, size: 288.3 KB)
# val: Scanning /content/yolo_tuna_dataset/labels/val... 85 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 85/85 1.4Kit/s 0.1s
# val: New cache created: /content/yolo_tuna_dataset/labels/val.cache
# Plotting labels to /content/tuna_runs/tuna_detection/labels.jpg...
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/tuna_runs/tuna_detection
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      1.11G      1.331      2.561      1.926          8        640: 100% ━━━━━━━━━━━━ 43/43 3.7it/s 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.7s
#                    all         85         85      0.692      0.325       0.16     0.0648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      1.32G      1.029      2.058      1.691          4        640: 100% ━━━━━━━━━━━━ 43/43 4.9it/s 8.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s
#                    all         85         85      0.224      0.691      0.374      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      1.34G      1.041      1.939      1.684          7        640: 100% ━━━━━━━━━━━━ 43/43 5.8it/s 7.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.8it/s 1.0s
#                    all         85         85      0.444      0.774      0.462        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      1.35G      1.003      1.898      1.664          4        640: 100% ━━━━━━━━━━━━ 43/43 4.7it/s 9.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all         85         85      0.274      0.837      0.472      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      1.37G      1.002      1.845      1.647          4        640: 100% ━━━━━━━━━━━━ 43/43 4.9it/s 8.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s
#                    all         85         85      0.554      0.308      0.249       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      1.39G     0.9637      1.805      1.611          4        640: 100% ━━━━━━━━━━━━ 43/43 5.7it/s 7.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.6it/s 0.8s
#                    all         85         85       0.78      0.547      0.578      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200       1.4G     0.9332      1.767      1.581          6        640: 100% ━━━━━━━━━━━━ 43/43 4.8it/s 9.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.5it/s 0.9s
#                    all         85         85      0.441      0.733      0.587      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      1.42G     0.9129      1.701      1.574          4        640: 100% ━━━━━━━━━━━━ 43/43 4.8it/s 8.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.2it/s 1.2s
#                    all         85         85      0.563      0.674        0.6      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      1.43G     0.8914      1.724      1.562          2        640: 100% ━━━━━━━━━━━━ 43/43 5.8it/s 7.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.4it/s 0.8s
#                    all         85         85      0.431      0.794       0.55      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      1.46G     0.8594      1.648      1.512          4        640: 100% ━━━━━━━━━━━━ 43/43 4.8it/s 9.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.6it/s 0.8s
#                    all         85         85      0.429      0.881      0.648      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      1.47G     0.8995       1.68      1.571          2        640: 100% ━━━━━━━━━━━━ 43/43 4.8it/s 9.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all         85         85      0.805      0.532      0.622      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      1.49G     0.8703      1.619      1.521          6        640: 100% ━━━━━━━━━━━━ 43/43 5.5it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.7it/s 1.3s
#                    all         85         85      0.529      0.765      0.753      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200      1.51G      0.827      1.571      1.502          2        640: 100% ━━━━━━━━━━━━ 43/43 5.3it/s 8.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all         85         85      0.466      0.913      0.788       0.73
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200      1.52G     0.7904      1.506      1.454          3        640: 100% ━━━━━━━━━━━━ 43/43 4.8it/s 8.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all         85         85      0.527      0.863      0.743      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      1.54G     0.8265      1.514      1.478          4        640: 100% ━━━━━━━━━━━━ 43/43 5.5it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.2it/s 1.4s
#                    all         85         85      0.576      0.849       0.77      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      1.56G     0.7954      1.494      1.466          4        640: 100% ━━━━━━━━━━━━ 43/43 5.2it/s 8.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 8.6it/s 0.7s
#                    all         85         85      0.693      0.801      0.813      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/200      1.56G     0.7846       1.51       1.47          4        640: 100% ━━━━━━━━━━━━ 43/43 4.6it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.1it/s 0.8s
#                    all         85         85      0.574      0.866      0.804      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      1.59G     0.7961      1.502      1.474          6        640: 100% ━━━━━━━━━━━━ 43/43 5.0it/s 8.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.9it/s 1.5s
#                    all         85         85      0.566      0.871      0.819      0.718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/200      1.61G     0.8074       1.46      1.465          2        640: 100% ━━━━━━━━━━━━ 43/43 5.5it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.7it/s 0.8s
#                    all         85         85      0.633       0.86       0.75      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/200      1.62G     0.7561      1.426      1.442          3        640: 100% ━━━━━━━━━━━━ 43/43 4.8it/s 9.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all         85         85      0.593      0.959      0.852      0.743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/200      1.64G     0.7782      1.409      1.442          8        640: 100% ━━━━━━━━━━━━ 43/43 4.7it/s 9.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all         85         85      0.542      0.904      0.818      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/200      1.66G     0.7593      1.393      1.435          3        640: 100% ━━━━━━━━━━━━ 43/43 5.5it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.9it/s 0.9s
#                    all         85         85      0.486      0.828      0.718      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/200      1.68G     0.7627      1.402      1.471          4        640: 100% ━━━━━━━━━━━━ 43/43 4.6it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.3it/s 1.0s
#                    all         85         85      0.586      0.951      0.859      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/200       1.7G     0.7725        1.4      1.459          6        640: 100% ━━━━━━━━━━━━ 43/43 4.6it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all         85         85      0.586      0.982      0.897      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/200       1.7G     0.7395      1.342      1.415          3        640: 100% ━━━━━━━━━━━━ 43/43 5.3it/s 8.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.1it/s 1.2s
#                    all         85         85      0.733      0.862      0.866      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/200      1.73G       0.76      1.355      1.456          7        640: 100% ━━━━━━━━━━━━ 43/43 4.9it/s 8.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 8.8it/s 0.7s
#                    all         85         85      0.788      0.804      0.884      0.803
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/200      1.74G     0.7591      1.342      1.437          2        640: 100% ━━━━━━━━━━━━ 43/43 4.6it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all         85         85      0.561      0.793      0.728       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/200      1.76G     0.7538      1.315      1.422          4        640: 100% ━━━━━━━━━━━━ 43/43 5.3it/s 8.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.7it/s 1.6s
#                    all         85         85      0.676      0.836      0.882      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/200      1.78G     0.7615       1.36      1.444          2        640: 100% ━━━━━━━━━━━━ 43/43 5.5it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.0it/s 0.9s
#                    all         85         85      0.658      0.901      0.855      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/200       1.8G     0.7442      1.314       1.41          8        640: 100% ━━━━━━━━━━━━ 43/43 4.6it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all         85         85      0.672      0.843      0.826      0.803
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/200      1.81G      0.716      1.242      1.383          4        640: 100% ━━━━━━━━━━━━ 43/43 4.9it/s 8.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.2it/s 1.4s
#                    all         85         85      0.663      0.932      0.872      0.818
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/200      1.83G     0.7224      1.292      1.386          3        640: 100% ━━━━━━━━━━━━ 43/43 5.7it/s 7.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.8it/s 0.9s
#                    all         85         85      0.617      0.872      0.811      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/200      1.84G     0.7314       1.34      1.395          7        640: 100% ━━━━━━━━━━━━ 43/43 4.6it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.8it/s 1.0s
#                    all         85         85      0.837       0.78      0.852      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/200      1.87G     0.7133      1.279      1.383          3        640: 100% ━━━━━━━━━━━━ 43/43 4.7it/s 9.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all         85         85      0.743      0.824      0.851      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/200      1.88G      0.704      1.222      1.389          4        640: 100% ━━━━━━━━━━━━ 43/43 5.5it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.1it/s 1.0s
#                    all         85         85      0.676      0.705      0.786      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/200       1.9G     0.7385      1.284      1.423          3        640: 100% ━━━━━━━━━━━━ 43/43 4.7it/s 9.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.8it/s 1.0s
#                    all         85         85      0.821      0.867      0.895      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/200      1.92G     0.6952      1.248      1.368          3        640: 100% ━━━━━━━━━━━━ 43/43 4.5it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 9.2it/s 0.6s
#                    all         85         85      0.888      0.788      0.916      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/200      1.93G      0.657      1.182       1.36          4        640: 100% ━━━━━━━━━━━━ 43/43 5.6it/s 7.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.0it/s 1.0s
#                    all         85         85       0.65      0.782      0.798      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/200      1.95G     0.6984      1.307      1.374          1        640: 100% ━━━━━━━━━━━━ 43/43 4.9it/s 8.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.0it/s 0.9s
#                    all         85         85      0.887      0.758      0.917      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/200      1.97G     0.6358      1.126      1.301          4        640: 100% ━━━━━━━━━━━━ 43/43 4.6it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 6.5it/s 0.9s
#                    all         85         85      0.818      0.866      0.919      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/200      1.97G     0.6714      1.183      1.361          4        640: 100% ━━━━━━━━━━━━ 43/43 5.8it/s 7.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.1it/s 1.9s
#                    all         85         85      0.598      0.916      0.883        0.8
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/200         2G     0.7226      1.266       1.38          2        640: 100% ━━━━━━━━━━━━ 43/43 5.0it/s 8.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.8it/s 1.0s
#                    all         85         85       0.89      0.874      0.934      0.896
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/200      2.02G     0.7185      1.222        1.4          8        640: 100% ━━━━━━━━━━━━ 43/43 4.5it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.1it/s 1.2s
#                    all         85         85      0.761      0.904      0.942      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/200      2.04G     0.6709       1.18      1.364          4        640: 100% ━━━━━━━━━━━━ 43/43 4.8it/s 8.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.9it/s 1.2s
#                    all         85         85      0.909       0.81      0.943      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/200      2.05G     0.7134      1.198      1.396          4        640: 100% ━━━━━━━━━━━━ 43/43 5.4it/s 8.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.9it/s 0.8s
#                    all         85         85      0.721       0.87      0.893      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/200      2.07G     0.6412      1.142      1.324          4        640: 100% ━━━━━━━━━━━━ 43/43 4.7it/s 9.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.2it/s 0.8s
#                    all         85         85      0.673      0.924      0.928        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/200      2.09G     0.6569      1.163      1.339          4        640: 100% ━━━━━━━━━━━━ 43/43 4.8it/s 9.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.2it/s 1.2s
#                    all         85         85      0.848      0.878       0.95      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/200       2.1G     0.6616      1.172      1.367          4        640: 100% ━━━━━━━━━━━━ 43/43 5.4it/s 7.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.8s
#                    all         85         85      0.791      0.769      0.876      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/200      2.11G     0.6424       1.12      1.344          2        640: 100% ━━━━━━━━━━━━ 43/43 5.1it/s 8.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.1it/s 0.8s
#                    all         85         85      0.884      0.881      0.967      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/200      2.14G      0.692       1.17      1.391          2        640: 100% ━━━━━━━━━━━━ 43/43 4.6it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.1it/s 1.2s
#                    all         85         85      0.841       0.93      0.977      0.969
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/200      2.15G     0.6714      1.111      1.354          2        640: 100% ━━━━━━━━━━━━ 43/43 4.8it/s 9.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.2it/s 1.2s
#                    all         85         85      0.898      0.839      0.959      0.932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/200      2.17G     0.6371      1.104      1.333          3        640: 100% ━━━━━━━━━━━━ 43/43 5.8it/s 7.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all         85         85      0.855      0.883       0.95      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/200      2.19G     0.6338      1.098      1.321          3        640: 100% ━━━━━━━━━━━━ 43/43 4.5it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.8it/s 0.8s
#                    all         85         85      0.862      0.822      0.939       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/200      2.21G     0.6418      1.104      1.322          4        640: 100% ━━━━━━━━━━━━ 43/43 4.5it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 7.5it/s 0.8s
#                    all         85         85      0.652       0.93      0.921       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/200
/s 7.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 9.1it/s 0.7s
#                    all         85         85      0.927      0.974      0.987      0.982
#
# 200 epochs completed in 0.564 hours.
# Optimizer stripped from /content/tuna_runs/tuna_detection/weights/last.pt, 6.3MB
# Optimizer stripped from /content/tuna_runs/tuna_detection/weights/best.pt, 6.3MB
#
# Validating /content/tuna_runs/tuna_detection/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s
#                    all         85         85      0.943      0.979       0.99      0.983
#                 bigeye         19         19      0.899      0.938      0.983      0.972
#                longfin         42         42      0.933          1      0.993      0.991
#              yellowfin         24         24      0.998          1      0.995      0.987
# Speed: 0.5ms preprocess, 3.7ms inference, 0.0ms loss, 6.1ms postprocess per image
# Results saved to /content/tuna_runs/tuna_detection
#
#  Training complete!
#  Best model saved at: tuna_runs/tuna_detection/weights/best.pt
#
#  Next: Evaluate the model to see how well it learned!

# %%
from ultralytics import YOLO
import numpy as np

# Load the best trained model
best_model = YOLO('tuna_runs/tuna_detection/weights/best.pt')

print(" Evaluating model on validation set...\n")
metrics = best_model.val()

print(f"\n Model Performance:")
print(f"  • mAP50: {metrics.box.map50:.4f}")
print(f"  • mAP50-95: {metrics.box.map:.4f}")

# Handle precision and recall (they are arrays, get mean)
if hasattr(metrics.box, 'p') and metrics.box.p is not None:
    precision = np.mean(metrics.box.p) if isinstance(metrics.box.p, np.ndarray) else metrics.box.p
    print(f"  • Precision (avg): {precision:.4f}")

if hasattr(metrics.box, 'r') and metrics.box.r is not None:
    recall = np.mean(metrics.box.r) if isinstance(metrics.box.r, np.ndarray) else metrics.box.r
    print(f"  • Recall (avg): {recall:.4f}")

# Show per-class performance
if hasattr(metrics, 'results_dict'):
    print(f"\n Per-Class Performance:")
    print(f"{'Class':<15} {'Precision':<12} {'Recall':<12} {'mAP50':<12}")
    print("-" * 51)

    # Get class names
    class_names = species_list if 'species_list' in locals() else ['Unknown']

    # Try to extract per-class metrics
    try:
        if hasattr(metrics.box, 'p') and isinstance(metrics.box.p, np.ndarray):
            for idx, class_name in enumerate(class_names):
                if idx < len(metrics.box.p):
                    prec = metrics.box.p[idx]
                    rec = metrics.box.r[idx] if hasattr(metrics.box, 'r') else 0
                    map50 = metrics.box.ap50[idx] if hasattr(metrics.box, 'ap50') else 0
                    print(f"{class_name:<15} {prec:<12.4f} {rec:<12.4f} {map50:<12.4f}")
    except:
        print("  (Per-class metrics not available)")

# Display confusion matrix and other plots
print("\n Training plots saved in: tuna_runs/tuna_detection/")

# Show training curves
from IPython.display import Image as IPImage, display

plot_path = Path('tuna_runs/tuna_detection')
plots = ['results.png', 'confusion_matrix.png', 'F1_curve.png', 'PR_curve.png']

for plot in plots:
    plot_file = plot_path / plot
    if plot_file.exists():
        print(f"\n📊 {plot}:")
        display(IPImage(filename=str(plot_file)))
    else:
        print(f"\n⚠️  {plot} not found")

print("\n Evaluation complete!")
print("\nUnderstanding the metrics:")
print("  • mAP50: Mean Average Precision at 50% IoU (higher is better)")
print("  • mAP50-95: mAP averaged over IoU thresholds 50%-95%")
print("  • Your mAP50 of 0.87 is VERY GOOD for such a small dataset!")
print("  • But remember: trained on only 20 images, so may not generalize well")
# Out:
#  Evaluating model on validation set...
#
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 314.3±82.3 MB/s, size: 9.1 KB)
# val: Scanning /content/yolo_tuna_dataset/labels/val.cache... 85 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 85/85 185.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.2s
#                    all         85         85      0.944      0.979       0.99      0.983
#                 bigeye         19         19      0.899      0.939      0.983      0.972
#                longfin         42         42      0.932          1      0.993      0.991
#              yellowfin         24         24          1      0.998      0.995      0.987
# Speed: 6.8ms preprocess, 5.4ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to /content/runs/detect/val
#
#  Model Performance:
#   • mAP50: 0.9905
#   • mAP50-95: 0.9833
#   • Precision (avg): 0.9439
#   • Recall (avg): 0.9788
#
#  Per-Class Performance:
# Class           Precision    Recall       mAP50
# ---------------------------------------------------
# bigeye          0.8992       0.9389       0.9832
# bluefin         0.9324       1.0000       0.9932
# longfin         1.0000       0.9975       0.9950
#
#  Training plots saved in: tuna_runs/tuna_detection/
#
# 📊 results.png:
# 📊 confusion_matrix.png:
# ⚠️  F1_curve.png not found
#
# ⚠️  PR_curve.png not found
#
#  Evaluation complete!
#
# Understanding the metrics:
#   • mAP50: Mean Average Precision at 50% IoU (higher is better)
#   • mAP50-95: mAP averaged over IoU thresholds 50%-95%
#   • Your mAP50 of 0.87 is VERY GOOD for such a small dataset!
#   • But remember: trained on only 20 images, so may not generalize well

# %%
import matplotlib.pyplot as plt
import cv2
from pathlib import Path
import random

print("🔍 Testing model on sample images...\n")

# Get random test images
test_images = list((yolo_dataset / 'images' / 'test').glob('*.*'))
sample_images = random.sample(test_images, min(6, len(test_images)))

# Run predictions
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

for idx, img_path in enumerate(sample_images):
    # Run prediction
    results = best_model(img_path, conf=0.25)

    # Get annotated image
    annotated = results[0].plot()
    annotated_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)

    # Display
    axes[idx].imshow(annotated_rgb)
    axes[idx].set_title(f"Prediction: {img_path.name}", fontsize=10)
    axes[idx].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 🔍 Testing model on sample images...
#
#
# image 1/1 /content/yolo_tuna_dataset/images/test/yellowfin_2.png: 320x640 1 bluefin, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/yolo_tuna_dataset/images/test/yellowfin_1.png: 384x640 1 bluefin, 1 yellowfin, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/yolo_tuna_dataset/images/test/bigeye_0.png: 384x640 1 bluefin, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
import cv2
import random
import matplotlib.pyplot as plt

def predict_tuna(image_path, conf_threshold=0.25):
    """
    Predict tuna species in an image

    Args:
        image_path: Path to image file
        conf_threshold: Confidence threshold (0-1)
    """
    results = best_model(image_path, conf=conf_threshold)

    # Display results
    annotated = results[0].plot()
    annotated_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(12, 8))
    plt.imshow(annotated_rgb)
    plt.axis('off')
    plt.title(f"Tuna Species Detection\nConfidence Threshold: {conf_threshold}")
    plt.show()

    # Print detections
    boxes = results[0].boxes
    if len(boxes) > 0:
        print("\n🐟 Detected Tuna Species:")
        for box in boxes:
            class_id = int(box.cls[0])
            confidence = float(box.conf[0])
            species_name = species_list[class_id]
            print(f"  • {species_name}: {confidence:.2%} confidence")
    else:
        print("\n❌ No tuna detected!")

    return results

# Test the function
print("🧪 Testing prediction function...")
test_images = list((yolo_dataset / 'images' / 'test').glob('*.*'))
if test_images:
    test_img = random.choice(test_images)
    predict_tuna(test_img, conf_threshold=0.3)
else:
    print("⚠️ No test images found!")
# Out:
# 🧪 Testing prediction function...
#
# image 1/1 /content/yolo_tuna_dataset/images/test/bigeye_48.jpg: 640x640 1 bigeye, 42.9ms
# Speed: 19.5ms preprocess, 42.9ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 640)
# 🐟 Detected Tuna Species:
#   • bigeye: 90.83% confidence

# %%
print(" Exporting model in different formats...\n")

# Export to ONNX (for deployment)
print("1 Exporting to ONNX format...")
best_model.export(format='onnx')

# Export to TorchScript
print("2 Exporting to TorchScript...")
best_model.export(format='torchscript')

# Export to TensorFlow Lite (for mobile)
print("3 Exporting to TFLite (mobile deployment)...")
try:
    best_model.export(format='tflite')
except:
    print("⚠️ TFLite export requires additional dependencies")

print("\n Model exports complete!")
print(" Exported models saved in: tuna_runs/tuna_detection/weights/")

# ============================================================================
# CELL 11: Download Trained Model
# ============================================================================
"""
Download your trained model to use locally
"""
from google.colab import files
import shutil

print(" Preparing model files for download...\n")

# Create a zip file with all important files
# !zip -r tuna_model.zip \
    tuna_runs/tuna_detection/weights/best.pt \
    tuna_runs/tuna_detection/weights/best.onnx \
    yolo_tuna_dataset/data.yaml \
    tuna_runs/tuna_detection/results.png \
    tuna_runs/tuna_detection/confusion_matrix.png

print("⬇ Downloading tuna_model.zip...")
files.download('tuna_model.zip')

print("\n Download complete!")
# Out:
#  Exporting model in different formats...
#
# 1 Exporting to ONNX format...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
#
# PyTorch: starting from 'tuna_runs/tuna_detection/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<=1.19.1', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 14 packages in 170ms
# Prepared 6 packages in 6.44s
# Installed 6 packages in 264ms
#  + colorama==0.4.6
#  + coloredlogs==15.0.1
#  + humanfriendly==10.0
#  + onnx==1.19.1
#  + onnxruntime-gpu==1.23.2
#  + onnxslim==0.1.78
#
# requirements: AutoUpdate success ✅ 7.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.78...
# ONNX: export success ✅ 8.8s, saved as 'tuna_runs/tuna_detection/weights/best.onnx' (11.7 MB)
#
# Export complete (9.3s)
# Results saved to /content/tuna_runs/tuna_detection/weights
# Predict:         yolo predict task=detect model=tuna_runs/tuna_detection/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=tuna_runs/tuna_detection/weights/best.onnx imgsz=640 data=yolo_tuna_dataset/data.yaml
# Visualize:       https://netron.app
# 2 Exporting to TorchScript...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
#
# PyTorch: starting from 'tuna_runs/tuna_detection/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (6.0 MB)
#
# TorchScript: starting export with torch 2.9.0+cu126...
# TorchScript: export success ✅ 1.8s, saved as 'tuna_runs/tuna_detection/weights/best.torchscript' (11.9 MB)
#
# Export complete (2.1s)
# Results saved to /content/tuna_runs/tuna_detection/weights
# Predict:         yolo predict task=detect model=tuna_runs/tuna_detection/weights/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=tuna_runs/tuna_detection/weights/best.torchscript imgsz=640 data=yolo_tuna_dataset/data.yaml
# Visualize:       https://netron.app
# 3 Exporting to TFLite (mobile deployment)...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
#
# PyTorch: starting from 'tuna_runs/tuna_detection/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx2tf>=1.26.3'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 12 packages in 7.52s
# Prepared 5 packages in 6.84s
# Installed 5 packages in 9ms
#  + ai-edge-litert==2.0.3
#  + backports-strenum==1.3.1
#  + onnx-graphsurgeon==0.5.8
#  + onnx2tf==1.28.5
#  + sng4onnx==1.0.4
#
# requirements: AutoUpdate success ✅ 14.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.78...
# ONNX: export success ✅ 0.9s, saved as 'tuna_runs/tuna_detection/weights/best.onnx' (11.8 MB)
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip': 100% ━━━━━━━━━━━━ 1.1MB 96.4MB/s 0.0s
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/calibration_image_sample_data_20x128x128x3_float32.npy...: 100% ━━━━━━━━━━━━ 1/1 47.3files/s 0.0s
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.5...
# Saved artifact at 'tuna_runs/tuna_detection/weights/best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 8, 8400), dtype=tf.float32, name=None)
# Captures:
#   140009809700688: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140009809701264: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   140009809701456: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140009809704144: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140009809704720: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   140009809705296: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140009809705872: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   140009809706064: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140012535218832: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535219216: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140009809706640: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   140009809706832: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140009809706448: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   140009809706256: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140009809702992: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535218256: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535221136: TensorSpec(shape=(1, 1, 48, 32), dtype=tf.float32, name=None)
#   140012535220752: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140012535220176: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140012535221520: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   140012535219408: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140012535221904: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140012535221328: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140012535223056: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535222096: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535223440: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140012535224400: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140012535222288: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140012535220944: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140012535223632: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140012535224592: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140012535221712: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140012535224976: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140012535222480: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535222864: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535225360: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   140012535224784: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140012535225552: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140012535223824: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   140012535225168: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140012535225936: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   140012535226128: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140012535226704: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535226512: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535228624: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140012535228816: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140012535226320: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140012535225744: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140012535228048: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140012535229008: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140012535227664: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140012535229392: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140012535226896: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535227088: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535229776: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   140012535229200: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140012535229968: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140012535228240: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   140012535229584: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140012535230352: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   140012535230544: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140012535231120: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535230928: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535233040: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140012535233232: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140012535230736: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140012535230160: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140012535231312: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535231504: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535233424: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   140012535232080: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140012535232464: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   140012535233808: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140012535232656: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   140012535233616: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140012535234192: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   140012535234000: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140013969686800: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969686608: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140012535234384: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969688912: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969689104: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969688336: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969687184: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969687376: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969689488: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   140013969689296: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140013969688528: TensorSpec(shape=(1, 1, 192, 64), dtype=tf.float32, name=None)
#   140013969687952: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969690064: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969689872: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969691984: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140013969692176: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140013969689680: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140013969686992: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140013969690256: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969690448: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969692560: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   140013969692368: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969692752: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140013969691408: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969691024: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969694672: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   140013969694096: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140013969695824: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969695632: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969698320: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969698512: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969697360: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969698896: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969696208: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969696400: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969696016: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   140013969697936: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140013969699088: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140013969695248: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140013969696976: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140013969698704: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   140013969700240: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140013969701584: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969701392: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969702160: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140013969701776: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140013969702544: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140013969700432: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140013969702352: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013969702736: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140013967672720: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   140013967672912: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140013967672144: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   140013967673104: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   140013969699472: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   140013969698128: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   140013969693520: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969693136: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013967673488: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013967673296: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969699280: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969699856: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969691600: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969692944: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013967674064: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013967672528: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969700624: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969697552: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969694288: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013969693328: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140013967673680: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013967673872: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969699664: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969700048: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969693904: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969693712: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013967674832: TensorSpec(shape=(1, 1, 64, 4), dtype=tf.float32, name=None)
#   140013967674256: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140013969701968: TensorSpec(shape=(1, 1, 64, 4), dtype=tf.float32, name=None)
#   140013969701200: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140013969695440: TensorSpec(shape=(1, 1, 64, 4), dtype=tf.float32, name=None)
#   140013969695056: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140013967674640: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013967674448: TensorSpec(shape=(4,), dtype=tf.float32, name=None)
#   140013969701008: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969700816: TensorSpec(shape=(4,), dtype=tf.float32, name=None)
#   140013969694480: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140013969694864: TensorSpec(shape=(4,), dtype=tf.float32, name=None)
#   140013967677136: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   140013967677328: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140013967671952: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140013967675792: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140013967675600: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140013967677712: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   140013967676944: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
# TensorFlow SavedModel: export success ✅ 36.3s, saved as 'tuna_runs/tuna_detection/weights/best_saved_model' (29.5 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as 'tuna_runs/tuna_detection/weights/best_saved_model/best_float32.tflite' (11.7 MB)
#
# Export complete (36.6s)
# Results saved to /content/tuna_runs/tuna_detection/weights
# Predict:         yolo predict task=detect model=tuna_runs/tuna_detection/weights/best_saved_model/best_float32.tflite imgsz=640
# Validate:        yolo val task=detect model=tuna_runs/tuna_detection/weights/best_saved_model/best_float32.tflite imgsz=640 data=yolo_tuna_dataset/data.yaml
# Visualize:       https://netron.app
#
#  Model exports complete!
#  Exported models saved in: tuna_runs/tuna_detection/weights/
#  Preparing model files for download...
#
#   adding: tuna_runs/tuna_detection/weights/best.pt (deflated 9%)
#   adding: tuna_runs/tuna_detection/weights/best.onnx (deflated 15%)
#   adding: yolo_tuna_dataset/data.yaml (deflated 29%)
#   adding: tuna_runs/tuna_detection/results.png (deflated 7%)
#   adding: tuna_runs/tuna_detection/confusion_matrix.png (deflated 30%)
# ⬇ Downloading tuna_model.zip...
#  Download complete!
